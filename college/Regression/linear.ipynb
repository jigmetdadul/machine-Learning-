# %%
import pandas as pd
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20.0, 10.0)

data = pd.read_csv('car data.csv')
print(data.shape)
data.head()
# Out:
# (301, 9)
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
X = data['Kms_Driven'].values
Y = data['Selling_Price'].values

# %%
meanX = np.mean(X)
meanY = np.mean(Y)
n = len(X)

nume = 0
denom = 0
for i in range(n):
    nume += (X[i] - meanX)*(Y[i] - meanY)
    denom += (X[i] - meanX)**2
b = nume/denom
a = meanY - (b*meanX)
print(a, b)
# Out:
# 4.520343021594407 3.814974792539448e-06

# %%
plt.xlabel('kms Driven')
plt.ylabel('selling price')
plt.scatter(X, Y, color = 'red', marker = '+')

# %%
result = a + b*450000
print(result)
# Out:
# 6.237081678237159

# %%
dataP = pd.read_csv('carPredict.csv')
plt.xlabel('kms Driven')
plt.ylabel('selling price')
plt.scatter(X, Y, color = 'red', marker = '+')
plt.plot(dataP.Kms_Driven, dataP.predictedPrice, color = 'blue')
